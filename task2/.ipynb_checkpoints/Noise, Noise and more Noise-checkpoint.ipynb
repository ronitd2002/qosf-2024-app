# %% [markdown]
# # Draper Addition circuit with artificial random noise

# %%
import numpy as np
from qiskit import QuantumCircuit, transpile, ClassicalRegister
from qiskit.quantum_info import Pauli
from qiskit.circuit import Gate

# %% [markdown]
# ### QFT and IQFT

# %%
def qft(circuit):
    n = circuit.num_qubits
    for i in range(n):
        circuit.h(i)
        for j in range(i + 1, n):
            circuit.cp(np.pi / 2**(j - i), j, i)
        #circuit.barrier()
    for i in range(n // 2):
        circuit.swap(i, n - i - 1)
    return circuit

def iqft(circuit):
    n = circuit.num_qubits
    for i in range(n // 2):
        circuit.swap(i, n - i - 1)
    for i in range(n - 1, -1, -1):
        #circuit.barrier()
        for j in range(i - 1, -1, -1):
            circuit.cp(-np.pi / 2**(i - j), i, j)
        circuit.h(i)
    return circuit

# %%
hello = qft(QuantumCircuit(4,4))
hello.draw('mpl')

# %%
bye = iqft(QuantumCircuit(4,4))
bye.draw('mpl')

# %%
def quantum_sum(a, b):
    n = max(len(format(a, 'b')), len(format(a, 'b'))) + 1
    circuit = QuantumCircuit(2 * n, n)
    for i in range(n):
        if (a >> i) & 1:
            circuit.x(i)
        if (b >> i) & 1:
            circuit.x(i + n)
    circuit = qft(circuit)
    for i in range(n):
        circuit.cx(i + n, i)
    circuit = iqft(circuit)
    return circuit

# %%
import qiskit.quantum_info as qi

qc = quantum_sum(1, 1)
qc.draw('mpl')

# %% [markdown]
# ### Noise insertion using random pauli gates

# %%
# Pauli Gates as custom quantum operations
pauli_gates = {'X': Gate("x", 1, []), 'Y': Gate("y", 1, []), 'Z': Gate("z", 1, [])}

def add_noise(circuit, alpha, beta):
    noisy_circuit = QuantumCircuit(circuit.num_qubits, circuit.num_qubits)
    for instr, qargs, _ in circuit:
        noisy_circuit.append(instr, qargs)
        noise_prob = alpha if instr.num_qubits == 1 else beta
        if np.random.rand() < noise_prob:
            noise_gate = pauli_gates[np.random.choice(['X', 'Y', 'Z'])]
            noisy_circuit.append(noise_gate, [qargs[0]])
    return noisy_circuit

# %%
noisy_qc = add_noise(qc, alpha=0.05, beta=0.1)
noisy_qc.draw('mpl')

# %% [markdown]
# # Simulation

# %%
from qiskit_aer import AerSimulator, StatevectorSimulator, Aer

sim = AerSimulator()
basis = ['cx', 'id', 'rz', 'sx', 'x']

ideal = transpile(qc, sim, basis_gates=basis)
nonideal = transpile(noisy_qc, sim, basis_gates=basis)

ideal.measure_all()
nonideal.measure_all()

# %%
ideal.draw('mpl')

# %%
nonideal.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = simulator.run(ideal).result()
sv = result.get_statevector(ideal)
print(sv)
# Out:
# Statevector([ 0.        +0.j        , -0.        +0.j        ,
#              -0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.62348836+0.78183263j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2, 2))

# %%
np.log2(np.asarray(sv).shape)
# Out:
# array([4.])

# %%
from qiskit.providers.basic_provider import BasicSimulator

simulator = BasicSimulator()
result = simulator.run(ideal).result()
counts = result.get_counts()
print(counts)
# Out:
# {'0110 00': 64, '1000 00': 137, '0100 00': 227, '0000 00': 207, '0011 00': 59, '1011 00': 54, '0001 00': 18, '1010 00': 61, '1110 00': 20, '0111 00': 18, '1100 00': 59, '1101 00': 14, '1111 00': 20, '1001 00': 63, '0101 00': 2, '0010 00': 1}

# %%
from qiskit.visualization import plot_histogram

plot_histogram(counts, color='crimson', title= "counts for basis")
