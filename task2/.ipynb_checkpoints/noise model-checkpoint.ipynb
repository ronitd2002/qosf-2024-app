# %% [markdown]
# # Quantum Arithmetic using QFT.

# %%
import numpy as np
from qiskit import QuantumCircuit, transpile, ClassicalRegister
from qiskit.quantum_info import Pauli
from qiskit.circuit import Gate

# %% [markdown]
# Transpilation function to the provided gate basis in the question namely: `[CX, ID, RZ, SX, X]`

# %%
from qiskit.circuit import Qubit, ClassicalRegister

def transform_to_basis(circuit):
    basis = ['cx', 'id', 'rz', 'sx', 'x']
    return transpile(circuit, basis_gates=basis)

# %% [markdown]
# QFT and IQFT circuits from scratch.

# %%
# write qft function from scratch
def qft(circuit):
    n = circuit.num_qubits
    for i in range(n):
        circuit.h(i)
        for j in range(i + 1, n):
            circuit.cp(np.pi / 2**(j - i), j, i)
        #circuit.barrier()
    for i in range(n // 2):
        circuit.swap(i, n - i - 1)

# write iqft function from scratch
def iqft(circuit):
    n = circuit.num_qubits
    for i in range(n // 2):
        circuit.swap(i, n - i - 1)
    for i in range(n - 1, -1, -1):
        #circuit.barrier()
        for j in range(i - 1, -1, -1):
            circuit.cp(-np.pi / 2**(i - j), i, j)
        circuit.h(i)

# %%
example = QuantumCircuit(4,4)
qft(example)
example.draw('mpl')

# %% [markdown]
# QFT circuit works ! No let's check for IQFT circuit

# %%
example_iqft = QuantumCircuit(4,4)
iqft(example_iqft)
example_iqft.draw('mpl')

# %% [markdown]
# IQFT circuit also works! Now let's build the summing circuit based on the draper addition paper.

# %%
def quantum_sum(a, b, n_bits):
    # circuit = n_bits + 1 (for "carry")
    qc = QuantumCircuit(2*n_bits + 1, n_bits + 1)

    # Initialize input registers
    for i in range(n_bits):
        if (a >> i) & 1:
            qc.x(i)
        if (b >> i) & 1:
            qc.x(i + n_bits)

    # Apply QFT to second register
    qft(qc)

    # Controlled rotations for addition
    for i in range(n_bits):
        for j in range(i + 1):
            qc.cp(2*np.pi/2**(i-j+1), j, n_bits+i)

    # Inverse QFT
    iqft(qc)

    # Measure
    qc.measure(range(n_bits), range(n_bits))

    return qc

# %%
qc = quantum_sum(1, 2, 2)
qc.draw('mpl')

# %%
transformed_qc = transform_to_basis(qc)
transformed_qc.draw('mpl')

# %% [markdown]
# #### Adding Noise

# %% [markdown]
# Adding noise function

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.circuit import Gate

# Pauli Gates as custom quantum operations
pauli_gates = {'X': Gate("x", 1, []), 'Y': Gate("y", 1, []), 'Z': Gate("z", 1, [])}

def add_noise(circuit, alpha, beta):
    noisy_circuit = QuantumCircuit(circuit.num_qubits, circuit.num_qubits)
    for instr, qargs, _ in circuit:
        noisy_circuit.append(instr, qargs)
        noise_prob = alpha if instr.num_qubits == 1 else beta
        if np.random.rand() < noise_prob:
            noise_gate = pauli_gates[np.random.choice(['X', 'Y', 'Z'])]
            noisy_circuit.append(noise_gate, [qargs[0]])
    return noisy_circuit

# %%
import qiskit.quantum_info as qi

# Example circuit with a = 1, b = 1, n = 2
qc = quantum_sum(1, 1, 2)

# Convert to gate basis and add noise
transformed_qc = transform_to_basis(qc)
noisy_qc = add_noise(transformed_qc, alpha=0.05, beta=0.1)

# Simulation and analysis
backend = qiskit.Aer.get_backend('statevector_simulator')
state_no_noise = qi.Statevector.from_instruction(transformed_qc).probabilities_dict()
state_with_noise = qi.Statevector.from_instruction(noisy_qc).probabilities_dict()

# Print Results
print("State without noise:", state_no_noise)
print("State with noise:", state_with_noise)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 8
#       6 # Convert to gate basis and add noise
#       7 transformed_qc = transform_to_basis(qc)
# ----> 8 noisy_qc = add_noise(transformed_qc, alpha=0.05, beta=0.1)
#      10 # Simulation and analysis
#      11 backend = qiskit.Aer.get_backend('statevector_simulator')
#
# Cell In[30], line 11, in add_noise(circuit, alpha, beta)
#       9 noisy_circuit = QuantumCircuit(circuit.num_qubits,circuit.num_qubits)
#      10 for instr, qargs, _ in circuit:
# ---> 11     noisy_circuit.append(instr, qargs)
#      12     noise_prob = alpha if instr.num_qubits == 1 else beta
#      13     if np.random.rand() < noise_prob:
#
# File ~/.local/lib/python3.12/site-packages/qiskit/circuit/quantumcircuit.py:1280, in QuantumCircuit.append(self, instruction, qargs, cargs)
#    1274 # For Operations that are non-Instructions, we use the Instruction's default method
#    1275 broadcast_iter = (
#    1276     operation.broadcast_arguments(expanded_qargs, expanded_cargs)
#    1277     if isinstance(operation, Instruction)
#    1278     else Instruction.broadcast_arguments(operation, expanded_qargs, expanded_cargs)
#    1279 )
# -> 1280 for qarg, carg in broadcast_iter:
#    1281     self._check_dups(qarg)
#    1282     instruction = CircuitInstruction(operation, qarg, carg)
#
# File ~/.local/lib/python3.12/site-packages/qiskit/circuit/measure.py:32, in Measure.broadcast_arguments(self, qargs, cargs)
#      30 def broadcast_arguments(self, qargs, cargs):
#      31     qarg = qargs[0]
# ---> 32     carg = cargs[0]
#      34     if len(carg) == len(qarg):
#      35         for qarg, carg in zip(qarg, carg):
#
# IndexError: list index out of range

# %%
import qiskit.quantum_info as qi
from qiskit_aer import AerSimulator
from qiskit.primitives import StatevectorSampler
import qiskit_ibm_runtime
#from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram, plot_distribution
#from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator

# %% [markdown]
# ### Simulation step
#
# We plan to run our addition circuit (also multiplication, if time permits) using the "simulated noise" function and also run it against depolarizing noise and Real hardware.

# %%
from qiskit_aer.primitives import SamplerV2
sim = AerSimulator()

ideal = transpile(transformed_qc, sim, optimization_level=0)
nonideal = transpile(noisy_qc, sim, optimization_level=0)

sampler = SamplerV2()
job = sampler.run([ideal, nonideal])
job_result = job.result()
print(f"counts for parameterized circuit : {job_result[0].data.c.get_counts()}")
# Out:
# counts for parameterized circuit : {'000000': 1024}

# %%
dist = job_result[0].data.c.get_counts()
plot_distribution(dist)#, filename='dist.png')

# %%
# Initialize your account
from qiskit_ibm_runtime import QiskitRuntimeService
provider = QiskitRuntimeService(channel='ibm_quantum', token="93a19268d9048dd117bf02ee07be14d56ef6f2213b383eb00733fa40402c052e91ad753cbbf23cfa5ab00d7e80700a84684d0c338500965e2a0dd033405ca96d")
service = QiskitRuntimeService(instance="ibm-q/open/main")
 
service.backends()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/api/session.py:329, in RetrySession.request(self, method, url, bare, **kwargs)
#     328     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 329     response.raise_for_status()
#     330 except RequestException as ex:
#     331     # Wrap the requests exceptions into a IBM Q custom one, for
#     332     # compatibility.
#
# File /usr/lib/python3/dist-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://auth.quantum-computing.ibm.com/api/users/loginWithToken
#
# The above exception was the direct cause of the following exception:
#
# IBMNotAuthorizedError                     Traceback (most recent call last)
# Cell In[83], line 4
#       2 from qiskit_ibm_runtime import QiskitRuntimeService
#       3 provider = QiskitRuntimeService(channel='ibm_quantum', token="93a19268d9048dd117bf02ee07be14d56ef6f2213b383eb00733fa40402c052e91ad753cbbf23cfa5ab00d7e80700a84684d0c338500965e2a0dd033405ca96d")
# ----> 4 service = QiskitRuntimeService(instance="ibm-q/open/main")
#       6 service.backends()
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:158, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, channel_strategy)
#     156     return
#     157 else:
# --> 158     auth_client = self._authenticate_ibm_quantum_account(self._client_params)
#     159     # Update client parameters to use authenticated values.
#     160     self._client_params.url = auth_client.current_service_urls()["services"]["runtime"]
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:334, in QiskitRuntimeService._authenticate_ibm_quantum_account(self, client_params)
#     327 if not version_info["new_api"] or "api-auth" not in version_info:
#     328     raise IBMInputValueError(
#     329         "The URL specified ({}) is not an IBM Quantum authentication URL. "
#     330         "Valid authentication URL: {}.".format(
#     331             client_params.url, QISKIT_IBM_RUNTIME_API_URL
#     332         )
#     333     )
# --> 334 auth_client = AuthClient(client_params)
#     335 service_urls = auth_client.current_service_urls()
#     336 if not service_urls.get("services", {}).get(SERVICE_NAME):
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/api/clients/auth.py:39, in AuthClient.__init__(self, client_params)
#      36 self._service_urls = {}  # type: ignore[var-annotated]
#      38 self.auth_api = Api(RetrySession(self.auth_url, **client_params.connection_parameters()))
# ---> 39 self.base_api = self._init_service_clients(**client_params.connection_parameters())
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/api/clients/auth.py:51, in AuthClient._init_service_clients(self, **request_kwargs)
#      42 """Initialize the clients used for communicating with the API.
#      43
#      44 Args:
#    (...)
#      48     Client for the API server.
#      49 """
#      50 # Request an access token.
# ---> 51 self.access_token = self._request_access_token()
#      52 self.auth_api.session.auth = QuantumAuth(access_token=self.access_token)
#      53 self._service_urls = self.user_urls()
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/api/clients/auth.py:77, in AuthClient._request_access_token(self)
#      67 """Request a new access token from the API authentication service.
#      68
#      69 Returns:
#    (...)
#      74     RequestsApiError: If the request failed.
#      75 """
#      76 try:
# ---> 77     response = self.auth_api.login(self.api_token)
#      78     return response["id"]
#      79 except RequestsApiError as ex:
#      80     # Get the original exception that raised.
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/api/rest/root.py:92, in Api.login(self, api_token)
#      83 """Login with token.
#      84
#      85 Args:
#    (...)
#      89     JSON response.
#      90 """
#      91 url = self.get_url("login")
# ---> 92 return self.session.post(url, json={"apiToken": api_token}).json()
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/qiskit_ibm_runtime/api/session.py:350, in RetrySession.request(self, method, url, bare, **kwargs)
#     348             message += f". {ex.response.text}"
#     349     if status_code == 401:
# --> 350         raise IBMNotAuthorizedError(message) from ex
#     351     raise RequestsApiError(message, status_code) from ex
#     353 return response
#
# IBMNotAuthorizedError: '401 Client Error: Unauthorized for url: https://auth.quantum-computing.ibm.com/api/users/loginWithToken. Login failed., Error code: 3446.'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
#provider = QiskitRuntimeService(channel='ibm_quantum', token="TOKEN apna daalna hai")
provider = QiskitRuntimeService(channel='ibm_quantum', token="93a19268d9048dd117bf02ee07be14d56ef6f2213b383eb00733fa40402c052e91ad753cbbf23cfa5ab00d7e80700a84684d0c338500965e2a0dd033405ca96d")
backend = provider.get_backend("ibm_brisbane")

# create sampler from the actual backend
sampler = SamplerV2.from_backend(backend)

# run a sampler job on the parameterized circuits with noise model of the actual hardware
bell_t = transpile(bell, AerSimulator(basis_gates=["ecr", "id", "rz", "sx"]), optimization_level=0)
job3 = sampler.run([bell_t], shots=128)
job_result = job3.result()
print(f"counts for Bell circuit w/noise: {job_result[0].data.meas.get_counts()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 10
#       7 sampler = SamplerV2.from_backend(backend)
#       9 # run a sampler job on the parameterized circuits with noise model of the actual hardware
# ---> 10 bell_t = transpile(bell, AerSimulator(basis_gates=["ecr", "id", "rz", "sx"]), optimization_level=0)
#      11 job3 = sampler.run([bell_t], shots=128)
#      12 job_result = job3.result()
#
# NameError: name 'bell' is not defined
